# %% [markdown]
# # Proyek Klasifikasi Gambar: Garbage Classification
# - **Nama:** Raihan Ahmad Abiyyu
# - **Email:** mc327d5y2198@student.devacademy.id
# - **ID Dicoding:** MC327D5Y2198

# %% [markdown]
# **Pengenalan Proyek: Klasifikasi Jenis Sampah dengan CNN**
#
# Pengelolaan limbah merupakan tantangan besar dalam menjaga kelestarian lingkungan hidup. Salah satu kunci dari sistem daur ulang yang efektif adalah proses pemilahan sampah berdasarkan jenisnya, yang hingga kini masih banyak dilakukan secara manual. Otomatisasi klasifikasi jenis sampah melalui model kecerdasan buatan dapat menjadi solusi untuk efisiensi dan efektivitas dalam manajemen limbah.
#
# Proyek ini bertujuan membangun model klasifikasi gambar berbasis Convolutional Neural Network (CNN) untuk mengenali berbagai kategori sampah berdasarkan citra visual. Dataset yang digunakan berasal dari Kaggle, yaitu:
#
# 🔗 [Garbage Classification (12 classes)](https://www.kaggle.com/datasets/mostafaabla/garbage-classification/data)
#
# Dataset ini berisi lebih dari 2000 gambar yang diklasifikasikan ke dalam 12 kategori berbeda:
# - cardboard
#
# - paper
#
# - plastic
#
# - metal
#
# - trash
#
# - green-glass
#
# - brown-glass
#
# - white-glass
#
# - clothes
#
# - shoes
#
# - battery
#
# - biological
#
# Keberagaman kelas ini membuat tantangan klasifikasi menjadi lebih menarik dan realistis, karena mencerminkan kondisi dunia nyata di mana sampah terdiri dari berbagai jenis bahan dan objek.

# %% [markdown]
# **Tujuan Proyek**
# 1. Mengembangkan model klasifikasi gambar menggunakan arsitektur CNN dengan Keras Sequential, yang menggunakan layer Conv2D dan MaxPooling.
# 2. Mempelajari dan mengenali berbagai jenis sampah dari gambar secara otomatis, sebagai langkah awal untuk sistem pemilah sampah berbasis AI.
# 3. Mengimplementasikan proses pembagian dataset menjadi training, validation, dan testing set guna menjaga kualitas pelatihan dan evaluasi model.
# 4. Mencapai akurasi minimal 85% pada training dan testing set untuk membuktikan efektivitas model.
# 5. Memvisualisasikan performa model melalui grafik akurasi dan loss selama proses pelatihan, serta mengevaluasi potensi overfitting/underfitting.
# 6. Menyimpan model dalam tiga format utama: SavedModel, TensorFlow Lite, dan TensorFlow.js untuk keperluan deployment lintas platform.

# %% [markdown]
# ### Reklasifikasi Data Limbah: Alasan dan Pertimbangan Teknis
#
# #### 1. Latar Belakang
#
# Dalam proyek *Garbage Image Classification* ini, digunakan dataset dari Kaggle berjudul **“Garbage Classification”**
# 🔗 [Link Dataset](https://www.kaggle.com/datasets/mostafaabla/garbage-classification)
#
# Dataset tersebut terdiri dari 12 kelas limbah:
#
# - `battery`
# - `biological`
# - `brown-glass`
# - `cardboard`
# - `clothes`
# - `green-glass`
# - `metal`
# - `paper`
# - `plastic`
# - `shoes`
# - `trash`
# - `white-glass`
#
# Meskipun sudah terklasifikasi, pengelompokkan ini masih bersifat umum karena belum mempertimbangkan:
# - Karakteristik kimia/fisika material
# - Proses pengolahan limbah sebenarnya
# - Risiko terhadap lingkungan dan kesehatan
#
# Oleh karena itu, dilakukan **reklasifikasi** agar sistem klasifikasi lebih sesuai dengan skenario manajemen limbah di dunia nyata.
#
# ---
#
# #### 2. Tujuan Reklasifikasi
#
# - Menyelaraskan dataset dengan sistem **pengolahan limbah** yang berlaku.
# - Memperjelas batas antar kelas berdasarkan **karakteristik dan metode penanganannya**.
# - Menghindari klasifikasi tumpang tindih dan meningkatkan **relevansi praktis** untuk deployment.
# - Menyederhanakan taksonomi limbah untuk pemrosesan otomatis dan sistem smart bins.
#
# ---
#
# #### 3. Dasar Pengelompokan Ulang
#
# Reklasifikasi dilakukan berdasarkan tiga aspek utama:
#
# 1. **Metode pengolahan limbah**: Kompos, daur ulang, insinerasi, B3
# 2. **Risiko terhadap kesehatan dan lingkungan**
# 3. **Karakteristik material** yang dapat dideteksi secara visual
#
# ---
#
# #### 4. Kategori Reklasifikasi
#
# | Kategori Baru         | Deskripsi                                                        | Kelas Asli                                  |
# |----------------------|------------------------------------------------------------------|---------------------------------------------|
# | `recyclable-paper`   | Kertas dan karton untuk pulping dan daur ulang                  | `paper`, `cardboard`                        |
# | `recyclable-glass`   | Kaca (warna berbeda) untuk dilebur kembali                      | `brown-glass`, `green-glass`, `white-glass`|
# | `recyclable-plastic` | Plastik rumah tangga yang dapat didaur ulang                    | `plastic`                                   |
# | `recyclable-metal`   | Logam seperti aluminium dan kaleng                              | `metal`                                     |
# | `organic`            | Limbah hayati/biologis untuk kompos                             | `biological`                                |
# | `textile`            | Pakaian dan alas kaki yang dapat digunakan ulang/upcycled       | `clothes`, `shoes`                          |
# | `hazardous`          | Limbah B3 seperti baterai, berbahaya dan butuh penanganan khusus| `battery`                                   |
# | `general-trash`      | Limbah residu tak bisa didaur ulang secara ekonomis             | `trash`                                     |
#
# ---
#
# #### 5. Alasan Khusus untuk Kategori `hazardous`
#
# `battery` dipisahkan menjadi `hazardous` karena:
#
# - Termasuk kategori **limbah B3 (Bahan Berbahaya dan Beracun)**
# - Mengandung **logam berat** (merkuri, kadmium, lithium)
# - Tidak bisa dibakar atau dicampur ke TPA biasa
# - Harus disimpan dan diangkut dengan **standar khusus**
# - Berisiko tinggi mencemari tanah, air, dan merusak lingkungan
#
# ---
#
# #### 6. Manfaat Reklasifikasi
#
# - Meningkatkan **akurasi dan akseptabilitas klasifikasi**
# - Memudahkan integrasi dengan sistem nyata (smart bins, bank sampah, TPS)
# - Menghindari **ambiguitas antara kelas** (misalnya `shoes` dan `clothes`)
# - Mendukung pengambilan keputusan untuk daur ulang, pembuangan, atau upcycling
# - Menyelaraskan klasifikasi dengan **regulasi dan SOP pengolahan limbah**
#
# ---
#
# #### 7. Penutup
#
# Reklasifikasi merupakan langkah awal yang penting untuk mengembangkan model AI yang **tidak hanya cerdas secara teknis**, tapi juga relevan dan aman secara ekologis.
#
# Langkah selanjutnya adalah mereorganisasi dataset ke dalam struktur folder berdasarkan kategori baru ini agar model dapat dilatih secara optimal.

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
# Pastikan tfjs-converter sudah terinstall
# !pip install tensorflowjs
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.1/89.1 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 3.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.2
#     Uninstalling packaging-24.2:
#       Successfully uninstalled packaging-24.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datasets 3.5.0 requires fsspec[http]<=2024.12.0,>=2023.1.0, but you have fsspec 2025.3.2 which is incompatible.
# nilearn 0.11.1 requires scikit-learn>=1.4.0, but you have scikit-learn 1.2.2 which is incompatible.
# pandas-gbq 0.26.1 requires google-api-core<3.0.0dev,>=2.10.2, but you have google-api-core 1.34.1 which is incompatible.
# bigframes 1.36.0 requires rich<14,>=12.4.4, but you have rich 14.0.0 which is incompatible.
# ...

# %%
import os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import shutil
import pandas as pd
import seaborn as sns
import cv2

from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.metrics import classification_report, confusion_matrix
# Out:
# 2025-04-18 02:44:21.895666: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744944262.087122      31 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744944262.141002      31 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# Ignore warnings for cleaner output
import warnings
warnings.filterwarnings('ignore')

# %%
# Check GPU
device_name = tf.config.list_physical_devices('GPU')
print("Available GPU:", device_name)
# !nvidia-smi
# Out:
# Available GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Fri Apr 18 02:44:35 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 560.35.03              Driver Version: 560.35.03      CUDA Version: 12.6     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla P100-PCIE-16GB           Off |   00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0             26W /  250W |       3MiB /  16384MiB |      0%      Default |
# ...

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# ### Data Loading

# %%
dataset_path = "/kaggle/input/garbage-reclassified/garbage_reclassified"

# %%
class_names = ['general-trash', 'hazardous', 'organic', 'recyclable-glass',
               'recyclable-metal', 'recyclable-paper', 'recyclable-plastic', 'textile']

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# #### Split Dataset

# %%
# Target directory
base_dir = '/content/garbage_dataset_split'
os.makedirs(base_dir, exist_ok=True)

splits = ['train', 'val', 'test']

# %%
# Buat folder struktur split
for split in splits:
    for cls in class_names:
        os.makedirs(os.path.join(base_dir, split, cls), exist_ok=True)

# %%
# Visualisasi distribusi kelas
def visualize_class_distribution(dataset_path, class_names):
    class_counts = []
    for cls in class_names:
        cls_path = os.path.join(dataset_path, cls)
        if os.path.exists(cls_path):
            count = len([f for f in os.listdir(cls_path) if f.endswith(('.jpg', '.jpeg', '.png'))])
            class_counts.append(count)
        else:
            class_counts.append(0)
            print(f"Warning: Class directory {cls_path} not found!")

    plt.figure(figsize=(12, 6))
    plt.bar(class_names, class_counts)
    plt.title('Distribution of Images per Class')
    plt.xlabel('Class Label')
    plt.ylabel('Number of Images')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

    # Return data for further use
    return dict(zip(class_names, class_counts))

# %%
# Visualisasi distribusi
class_distribution = visualize_class_distribution(dataset_path, class_names)
print("Class distribution:", class_distribution)
# Out:
# Class distribution: {'general-trash': 697, 'hazardous': 945, 'organic': 985, 'recyclable-glass': 2011, 'recyclable-metal': 769, 'recyclable-paper': 1941, 'recyclable-plastic': 865, 'textile': 7302}

# %%
# Fungsi split per kelas dengan stratified sampling
def split_class_images(cls_name, source_dir, dest_base, train_size=0.7, val_size=0.15):
    cls_path = os.path.join(source_dir, cls_name)
    if not os.path.exists(cls_path):
        print(f"Skipping {cls_name}, directory not found!")
        return

    images = [f for f in os.listdir(cls_path) if f.endswith(('.jpg', '.jpeg', '.png'))]

    # Stratified split untuk memastikan distribusi seimbang
    train_imgs, temp_imgs = train_test_split(images, train_size=train_size, random_state=42)
    val_imgs, test_imgs = train_test_split(temp_imgs, test_size=0.5, random_state=42)

    print(f"Kelas {cls_name}: {len(images)} gambar → Train: {len(train_imgs)}, Val: {len(val_imgs)}, Test: {len(test_imgs)}")

    # Copy gambar ke folder tujuan
    for img in train_imgs:
        shutil.copy(os.path.join(cls_path, img), os.path.join(dest_base, 'train', cls_name, img))
    for img in val_imgs:
        shutil.copy(os.path.join(cls_path, img), os.path.join(dest_base, 'val', cls_name, img))
    for img in test_imgs:
        shutil.copy(os.path.join(cls_path, img), os.path.join(dest_base, 'test', cls_name, img))

# %%
# Lakukan split semua kelas
for cls in class_names:
    split_class_images(cls, dataset_path, base_dir)
# Out:
# Kelas general-trash: 697 gambar → Train: 487, Val: 105, Test: 105
# Kelas hazardous: 945 gambar → Train: 661, Val: 142, Test: 142
# Kelas organic: 985 gambar → Train: 689, Val: 148, Test: 148
# Kelas recyclable-glass: 2011 gambar → Train: 1407, Val: 302, Test: 302
# Kelas recyclable-metal: 769 gambar → Train: 538, Val: 115, Test: 116
# Kelas recyclable-paper: 1941 gambar → Train: 1358, Val: 291, Test: 292
# Kelas recyclable-plastic: 865 gambar → Train: 605, Val: 130, Test: 130
# Kelas textile: 7302 gambar → Train: 5111, Val: 1095, Test: 1096

# %% [markdown]
# #### Augmentasi Gambar

# %%
# Hitung class weights untuk mengatasi imbalance
def calculate_class_weights(directory):
    class_counts = {}
    for cls in class_names:
        cls_dir = os.path.join(directory, cls)
        if os.path.exists(cls_dir):
            class_counts[cls] = len([f for f in os.listdir(cls_dir) if f.endswith(('.jpg', '.jpeg', '.png'))])
        else:
            class_counts[cls] = 0

    total = sum(class_counts.values())
    # Inverse weighting - kelas dengan lebih sedikit sampel mendapat bobot lebih tinggi
    weights = {i: total / (len(class_counts) * count) if count > 0 else 1.0
               for i, (cls, count) in enumerate(class_counts.items())}
    return weights

# %%
# Augmentasi data yang lebih agresif untuk kelas minoritas
train_datagen_minority = ImageDataGenerator(
    rescale=1./255,
    rotation_range=40,
    zoom_range=0.3,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.7, 1.3],
    fill_mode='nearest'
)

# Augmentasi data standar untuk kelas mayoritas
train_datagen_majority = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    zoom_range=0.2,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    fill_mode='nearest'
)

# Validasi dan test tanpa augmentasi
val_test_datagen = ImageDataGenerator(rescale=1./255)

img_size = (224, 224)
batch_size = 32  # Lebih kecil untuk Kaggle

# %%
# Fungsi untuk mengidentifikasi kelas mayoritas (textile) vs minoritas
def is_minority_class(class_name):
    return class_name != 'textile'  # textile adalah kelas mayoritas

# Memuat data dengan augmentasi yang disesuaikan per kelas
def create_balanced_generator(directory, batch_size):
    generators = []

    # Buat generator terpisah untuk setiap kelas
    for cls in class_names:
        class_dir = os.path.join(directory, cls)
        if is_minority_class(cls):
            gen = train_datagen_minority.flow_from_directory(
                directory, # Use the parent directory
                target_size=img_size,
                batch_size=batch_size // len(class_names),
                class_mode='categorical', # Ensure class_mode is 'categorical' for one-hot encoding
                # Removed the classes argument as it was interfering with the label generation
                shuffle=True
            )
        else:
            gen = train_datagen_majority.flow_from_directory(
                directory, # Use the parent directory
                target_size=img_size,
                batch_size=batch_size // len(class_names),
                class_mode='categorical', # Ensure class_mode is 'categorical' for one-hot encoding
                # Removed the classes argument as it was interfering with the label generation
                shuffle=True
            )
        generators.append(gen)

    # Menggabungkan batch dari semua generator
    while True:
        batches = []
        for gen in generators:
            batch = next(gen)
            batches.append(batch)

        # Menggabungkan batch dari semua kelas
        x = np.concatenate([batch[0] for batch in batches])
        y = np.concatenate([batch[1] for batch in batches])

        # Shuffle batch gabungan
        indices = np.random.permutation(len(x))
        yield x[indices], y[indices]

# %%
# Buat generator untuk training yang balanced
train_generator = create_balanced_generator(os.path.join(base_dir, 'train'), batch_size)

# %%
# Generator standard untuk validasi dan testing
val_generator = val_test_datagen.flow_from_directory(
    os.path.join(base_dir, 'val'),
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical'
)

test_generator = val_test_datagen.flow_from_directory(
    os.path.join(base_dir, 'test'),
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False  # untuk evaluasi model
)
# Out:
# Found 2328 images belonging to 8 classes.
# Found 2331 images belonging to 8 classes.

# %% [markdown]
# ## Modelling

# %%
def create_model(input_shape=(224, 224, 3), num_classes=8):
    model = Sequential([
        # Block 1
        Conv2D(64, (3, 3), padding='same', activation='relu', input_shape=input_shape),
        Conv2D(64, (3, 3), padding='same', activation='relu'),
        BatchNormalization(),
        MaxPooling2D(2, 2),

        # Block 2
        Conv2D(128, (3, 3), padding='same', activation='relu'),
        Conv2D(128, (3, 3), padding='same', activation='relu'),
        BatchNormalization(),
        MaxPooling2D(2, 2),
        Dropout(0.2),

        # Block 3
        Conv2D(256, (3, 3), padding='same', activation='relu'),
        Conv2D(256, (3, 3), padding='same', activation='relu'),
        Conv2D(256, (3, 3), padding='same', activation='relu'),  # Tambah satu layer konvolusi lagi
        BatchNormalization(),
        MaxPooling2D(2, 2),
        Dropout(0.3),

        # Block 4
        Conv2D(512, (3, 3), padding='same', activation='relu'),
        Conv2D(512, (3, 3), padding='same', activation='relu'),
        Conv2D(512, (3, 3), padding='same', activation='relu'),  # Tambah satu layer konvolusi lagi
        BatchNormalization(),
        MaxPooling2D(2, 2),
        Dropout(0.4),

        # Block 5
        Conv2D(512, (3, 3), padding='same', activation='relu'),
        Conv2D(512, (3, 3), padding='same', activation='relu'),
        BatchNormalization(),
        MaxPooling2D(2, 2),
        Dropout(0.4),

        # Fully connected layers
        Flatten(),
        Dense(1024, activation='relu'),  # Lebih banyak neuron
        BatchNormalization(),
        Dropout(0.5),
        Dense(512, activation='relu'),
        BatchNormalization(),
        Dropout(0.5),
        Dense(num_classes, activation='softmax')
    ])
    return model

# %%
# Buat model
model = create_model(input_shape=(img_size[0], img_size[1], 3), num_classes=len(class_names))
# Out:
# I0000 00:00:1744944429.318626      31 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
# Compile model
optimizer = Adam(learning_rate=0.0001)
model.compile(
    loss='categorical_crossentropy',
    optimizer=optimizer,
    metrics=['accuracy']
)

# %%
# Tampilkan ringkasan model
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 224, 224, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 224, 224, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 224, 224, 64)        │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# ...

# %%
# Callback untuk menyimpan model terbaik dan mencegah overfitting
callbacks = [
    EarlyStopping(
        monitor='val_accuracy',
        patience=15,  # Lebih banyak patience untuk training yang lebih lama
        restore_best_weights=True,
        verbose=1
    ),
    ModelCheckpoint(
        filepath='/kaggle/working/best_model.keras',  # lokasi writable
        monitor='val_loss',
        save_best_only=True,
        mode='min',
        verbose=1
    ),
    ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=5,
        min_lr=1e-6,
        verbose=1
    )
]

# %%
# Hitung jumlah step per epoch
steps_per_epoch = sum([len(os.listdir(os.path.join(base_dir, 'train', cls)))
                      for cls in class_names if os.path.exists(os.path.join(base_dir, 'train', cls))]) // batch_size

# %% [markdown]
# Model sebelumnya telah dilatih hingga epoch 42, kemudian koneksi terputus, namun sudah di save.

# %%
# Training model
# print("Mulai training model...")
# history = model.fit(
#    train_generator,
#    steps_per_epoch=steps_per_epoch,
#    validation_data=val_generator,
#    epochs=250,  # Maximum epochs
#    callbacks=callbacks
# )

# %% [markdown]
# Melanjutkan training model dari checkpoint sebelum terputus

# %%
# Memuat model terbaik yang sudah disimpan
model = load_model('/kaggle/input/latest/keras/default/1/best_model.keras')

# Tentukan epoch yang sudah dilalui
initial_epoch = 42

# Melanjutkan training
history = model.fit(
    train_generator,
    steps_per_epoch=steps_per_epoch,
    validation_data=val_generator,
    epochs=250,  # Total epochs yang ingin dilalui
    initial_epoch=initial_epoch,  # Melanjutkan dari epoch terakhir
    callbacks=callbacks
)
# Out:
# Found 10856 images belonging to 8 classes.
# Found 10856 images belonging to 8 classes.
# Found 10856 images belonging to 8 classes.
# Found 10856 images belonging to 8 classes.
# Found 10856 images belonging to 8 classes.
# Found 10856 images belonging to 8 classes.
# Found 10856 images belonging to 8 classes.
# Found 10856 images belonging to 8 classes.
# Epoch 43/250
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1744944444.848212     118 service.cc:148] XLA service 0x7f96e40043e0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1744944444.849216     118 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1744944445.809526     118 cuda_dnn.cc:529] Loaded cuDNN version 90300
# ...

# %% [markdown]
# ## Evaluasi dan Visualisasi

# %%
# Evaluasi model
test_loss, test_acc = model.evaluate(test_generator)
print(f"Test accuracy: {test_acc*100:.2f}%")
print(f"Test loss: {test_loss:.4f}")
# Out:
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 11s 147ms/step - accuracy: 0.8078 - loss: 0.5959
# Test accuracy: 87.47%
# Test loss: 0.3816

# %%
# Plot history training
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.tight_layout()
plt.show()

# %%
# Evaluasi per kelas
y_pred = model.predict(test_generator)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = test_generator.classes
# Out:
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 6s 76ms/step

# %%
# Confusion matrix
cm = confusion_matrix(y_true, y_pred_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %%
# Classification report
print("Classification Report:")
print(classification_report(y_true, y_pred_classes, target_names=class_names))
# Out:
# Classification Report:
#                     precision    recall  f1-score   support
#
#      general-trash       0.85      0.69      0.76       105
#          hazardous       0.91      0.73      0.81       142
#            organic       0.93      0.85      0.89       148
#   recyclable-glass       0.84      0.85      0.85       302
#   recyclable-metal       0.72      0.69      0.70       116
#   recyclable-paper       0.90      0.82      0.86       292
# recyclable-plastic       0.76      0.73      0.75       130
#            textile       0.90      0.97      0.93      1096
#
#           accuracy                           0.87      2331
#          macro avg       0.85      0.79      0.82      2331
#       weighted avg       0.87      0.87      0.87      2331

# %% [markdown]
# ## Konversi Model

# %% [markdown]
# SavedModel

# %%
saved_model_path = "exported/saved_model"
os.makedirs(saved_model_path, exist_ok=True)

# Simpan dalam format SavedModel (Keras 3 style)
model.export(saved_model_path)

print("✅ SavedModel berhasil disimpan di:", saved_model_path)
# Out:
# Saved artifact at 'exported/saved_model'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer')
# Output Type:
#   TensorSpec(shape=(None, 8), dtype=tf.float32, name=None)
# Captures:
#   140289533844304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140289533842576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140289533843920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140289533842768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140289533536272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140289533537232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140289533844112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140289533531856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140289533534352: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ...

# %% [markdown]
# TFLite

# %%
# Konversi ke TFLite
converter = tf.lite.TFLiteConverter.from_saved_model(saved_model_path)
tflite_model = converter.convert()

tflite_dir = "exported/tflite"
os.makedirs(tflite_dir, exist_ok=True)

# Simpan model.tflite
with open(f"{tflite_dir}/model.tflite", "wb") as f:
    f.write(tflite_model)

# (Optional) Simpan label.txt placeholder
with open(f"{tflite_dir}/label.txt", "w") as f:
    f.write("Label_1\nLabel_2\n...")  # Ganti sesuai label kamu

print("✅ Model berhasil dikonversi ke TFLite.")
# Out:
# W0000 00:00:1744951126.968671      31 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1744951126.968724      31 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# ✅ Model berhasil dikonversi ke TFLite.

# %% [markdown]
# TFJS

# %%
# !tensorflowjs_converter \
    --input_format=keras \
    /content/saved_model.h5 \
    /content/tfjs_model
# Out:
# 2025-04-18 06:06:53.860627: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744956413.912852    6765 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744956413.930314    6765 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 🌲 Try https://ydf.readthedocs.io, the successor of TensorFlow Decision Forests with more features and faster training!
# failed to lookup keras version from the file,
#     this is likely a weight only file

# %% [markdown]
# Ringkasan Struktur Folder dan Ukuran

# %%
def summarize_exported_folder(base_path="exported"):
    print("📦 Struktur folder dan ukuran file:\n")

    for root, dirs, files in os.walk(base_path):
        level = root.replace(base_path, "").count(os.sep)
        indent = "│   " * level + "├── "
        print(f"{indent}{os.path.basename(root)}/")
        subindent = "│   " * (level + 1)
        for f in files:
            size = os.path.getsize(os.path.join(root, f)) / 1024
            print(f"{subindent}└── {f} ({size:.2f} KB)")

summarize_exported_folder()
# Out:
# 📦 Struktur folder dan ukuran file:
#
# ├── exported/
# │   ├── saved_model/
# │   │   └── fingerprint.pb (0.06 KB)
# │   │   └── saved_model.pb (352.30 KB)
# │   │   ├── variables/
# │   │   │   └── variables.data-00000-of-00001 (301473.25 KB)
# │   │   │   └── variables.index (6.96 KB)
# │   │   ├── assets/
# │   ├── tfjs_model/
# │   ├── tflite/
# │   │   └── label.txt (0.02 KB)
# │   │   └── model.tflite (150706.39 KB)

# %% [markdown]
# Ekstrak requirements.txt

# %%
# !pip freeze > requirements.txt

# %%
# Cek isi file requirements.txt
with open("requirements.txt", "r") as f:
    print(f.read())
# Out:
# absl-py==1.4.0
# accelerate==1.3.0
# aiofiles==22.1.0
# aiohappyeyeballs==2.6.1
# aiohttp==3.11.16
# aiosignal==1.3.2
# aiosqlite==0.21.0
# alabaster==1.0.0
# albucore==0.0.23
# albumentations==2.0.4
# ale-py==0.10.1
# alembic==1.15.2
# altair==5.5.0
# annotated-types==0.7.0
# annoy==1.17.3
# ansicolors==1.1.8
# antlr4-python3-runtime==4.9.3
# anyio==3.7.1
# argon2-cffi==23.1.0
# argon2-cffi-bindings==21.2.0
# args==0.1.0
# array_record==0.6.0
# arrow==1.3.0
# arviz==0.20.0
# astropy==7.0.1
# astropy-iers-data==0.2025.2.10.0.33.26
# asttokens==3.0.0
# astunparse==1.6.3
# atpublic==4.1.0
# attrs==25.3.0
# audioread==3.0.1
# autograd==1.7.0
# babel==2.17.0
# backcall==0.2.0
# bayesian-optimization==2.0.3
# beartype==0.20.2
# beautifulsoup4==4.13.3
# betterproto==2.0.0b6
# bigframes==1.36.0
# bigquery-magics==0.5.0
# bleach==6.2.0
# blinker==1.9.0
# blis==0.7.11
# blobfile==3.0.0
# blosc2==3.1.0
# bokeh==3.6.3
# Boruta==0.4.3
# boto3==1.37.29
# botocore==1.37.29
# Bottleneck==1.4.2
# ...

# %% [markdown]
# ## Inference (Optional)
